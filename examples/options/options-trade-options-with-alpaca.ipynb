# %% [markdown]
# > <b>Note: This Jupyter Notebook is associated with the article: [How To Trade Options with Alpaca's Dashboard and Trading API](https://alpaca.markets/learn/how-to-trade-options-with-alpaca).</b>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alpacahq/alpaca-py/blob/master/examples/options/options-trade-options-with-alpaca.ipynb)

# %% [markdown]
# ## Options Trading Using Alpaca-py

# %% [markdown]
# ### 1. Setup

# %%
# 1.1 Install / Update Alpaca-py
# !pip install --upgrade alpaca-py
# Out:
# Requirement already satisfied: alpaca-py in /Users/georgia/miniconda3/lib/python3.13/site-packages (0.37.0)
# Collecting alpaca-py
#   Downloading alpaca_py-0.43.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from alpaca-py) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from alpaca-py) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from alpaca-py) (2.10.3)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from alpaca-py) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from alpaca-py) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from alpaca-py) (10.4)
# Requirement already satisfied: numpy>=1.26.0 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from pandas>=1.5.3->alpaca-py) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from pandas>=1.5.3->alpaca-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from pandas>=1.5.3->alpaca-py) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from pandas>=1.5.3->alpaca-py) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /Users/georgia/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->alpaca-py) (1.17.0)
# Downloading alpaca_py-0.43.1-py3-none-any.whl (122 kB)
# Installing collected packages: alpaca-py
#   Attempting uninstall: alpaca-py
#     Found existing installation: alpaca-py 0.37.0
#     Uninstalling alpaca-py-0.37.0:
#       Successfully uninstalled alpaca-py-0.37.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# finrl 0.3.8 requires alpaca-py<0.38,>=0.37, but you have alpaca-py 0.43.1 which is incompatible.
# Successfully installed alpaca-py-0.43.1

# %%
# 1.2 Import Necessary Packages
import json
from datetime import datetime, timedelta
import os

import pandas as pd
from dotenv import load_dotenv
from zoneinfo import ZoneInfo

from alpaca.trading.client import TradingClient
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit
from alpaca.data.historical.stock import StockHistoricalDataClient, StockLatestTradeRequest
from alpaca.data.historical.option import OptionHistoricalDataClient
from alpaca.trading.stream import TradingStream
from alpaca.data.live.option import OptionDataStream

from alpaca.data.requests import (
    OptionBarsRequest,
    OptionTradesRequest,
    OptionLatestQuoteRequest,
    OptionLatestTradeRequest,
    OptionSnapshotRequest,
    OptionChainRequest
)
from alpaca.trading.requests import (
    GetOptionContractsRequest,
    GetAssetsRequest,
    MarketOrderRequest,
    GetOrdersRequest,
    ClosePositionRequest,
    OptionLegRequest
)
from alpaca.trading.enums import (
    AssetStatus,
    ExerciseStyle,
    OrderSide,
    OrderClass,
    OrderType,
    TimeInForce,
    QueryOrderStatus,
    ContractType
)
from alpaca.common.exceptions import APIError

# %%
# Please safely store your API keys and never commit them to the repository (use .gitignore)
# Load environment variables from environment file (e.g. .env)
load_dotenv()

TRADE_API_KEY = os.environ.get('ALPACA_API_KEY')
TRADE_API_SECRET = os.environ.get('ALPACA_SECRET_KEY')

# We use paper environment for this example
ALPACA_PAPER_TRADE = True

# Below are the variables for development this documents so please do not change these variables
TRADE_API_WSS = None
DATA_API_URL = None
OPTION_STREAM_DATA_WSS = None

# %% [markdown]
# ### 2. Setup clients
#
# Load API keys securely from a .env file\
# You can get them from https://alpaca.markets/
#
# * Step 1: Create a file named `.env` in your project root (same folder as this notebook)
# * Step 2: Add your paper (live) trading keys in this format:
#     * ALPACA_API_KEY=your_actual_api_key
#     * ALPACA_SECRET_KEY=your_actual_secret_key
# * Step 3: Make sure you have the 'python-dotenv' package installed:
#     `!pip install python-dotenv`

# %%
# To enable live trading, replace `ALPACA_PAPER_TRADE = True` with `ALPACA_PAPER_TRADE = False` to disable the paper trading configuration
trade_client = TradingClient(api_key=TRADE_API_KEY, secret_key=TRADE_API_SECRET, paper=ALPACA_PAPER_TRADE)
stock_data_client = StockHistoricalDataClient(api_key=TRADE_API_KEY, secret_key=TRADE_API_SECRET)

# %% [markdown]
# ### 3. Check trading account

# %%
# Check account related information
acc = trade_client.get_account()
acc
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA3YBODY0KKO',
#     'accrued_fees': '0',
#     'buying_power': '199997.76',
#     'cash': '99998.88',
#     'created_at': datetime.datetime(2025, 10, 8, 16, 21, 46, 715374, tzinfo=TzInfo(UTC)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '0',
#     'equity': '99998.88',
#     'id': UUID('bea91e64-7f44-48ea-bf50-9ee2f8bff3c1'),
#     'initial_margin': '0',
#     'last_equity': '99998.88',
#     'last_maintenance_margin': '0',
#     'long_market_value': '0',
#     'maintenance_margin': '0',
#     'multiplier': '2',
#     'non_marginable_buying_power': '99998.88',
#     'options_approved_level': 3,
#     'options_buying_power': '99998.88',
#     'options_trading_level': 3,
#     'pattern_day_trader': False,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
#     'portfolio_value': '99998.88',
#     'regt_buying_power': '199997.76',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '99998.88',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}

# %% [markdown]
# ### 4. Check account configuration

# %%
# Check account configurations
acct_config = trade_client.get_account_configurations()
acct_config
# Out:
# {   'dtbp_check': <DTBPCheck.ENTRY: 'entry'>,
#     'fractional_trading': True,
#     'max_margin_multiplier': '4',
#     'max_options_trading_level': None,
#     'no_shorting': False,
#     'pdt_check': <PDTCheck.ENTRY: 'entry'>,
#     'ptp_no_exception_entry': False,
#     'suspend_trade': False,
#     'trade_confirm_email': <TradeConfirmationEmail.ALL: 'all'>}

# %% [markdown]
# ### 5. Retrieve list of assets which are options enabled

# %%
# We can filter assets by `options_enabled` attribute
# Asset object has `options_enabled` attribute if it is options enabled
req = GetAssetsRequest(
  attributes = "options_enabled"  
)
assets = trade_client.get_all_assets(req)
assets
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('1410afb3-ce61-45eb-ba3e-c7d7ba428a31'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'DIXIE GROUP INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'DXYN',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a4e9d43c-83fb-43d1-8e0d-b403f51f28a2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ADVENT TECHNOLOGIES HLDGS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ADNH',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('59690a61-cd01-4947-bc71-ac93309fbd91'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CHARGE ENTERPRISES INC COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'CRGEQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('7f1bd20c-50e7-43d8-a5c1-5b551a8988b8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ENZO BIOCHEM INC COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ENZB',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('0def50ea-ac61-4275-a285-0848875d6bba'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'VERTEX ENERGY INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'VTNRQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('0a9416b8-b627-4f5a-89c6-91d535142456'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CORENERGY INFRASTRUCTURE TR INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'CORRQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('34d64d14-411d-4b96-a508-7428bbd6c529'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'AIRSPAN NETWORKS HLDGS INC COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MIMOQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a53429dc-52e1-4d60-9d76-b53a3a60cadd'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Nemaura Medical, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'NMRD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('eaeca590-762d-4930-965d-f15aac439d41'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Leafly Holdings, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LFLYD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('c945a8a3-8975-4bbe-8f7a-3961bafe150b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Vintage Wine Estates, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'VWESQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('162c893c-c085-4862-9311-e98633dda8e7'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Vaxart, Inc Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'VXRT',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6f1d10a7-20ba-4ef0-835c-1313cc7b9ce4'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ADAPTIMMUNE THERAPEUTICS PLC American Depositary Shares - '
#              'Sponsored',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ADAPY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('c7a520be-6d83-4d66-9a23-0dc5fe276130'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'TELESIS BIO INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'TBIO',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('cc492b87-aff1-442a-99bb-e4e638dd6e98'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'U Power Limited Class A Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'UCAR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('981d6d74-2de2-4b90-b60c-7f09922b00d1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Cumulus Media Inc. Class A Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'CMLS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('0abc2677-755e-467f-b23c-263748444774'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ISUN INC COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ISUNQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('ca548c98-c376-478c-9d80-1e345432bb7f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SUNNOVA ENERGY INTL INC',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'NOVAQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('292eb02d-93d1-4131-b71f-5d4162f508eb'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CONTAINER STORE GROUP INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'TCSGQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('7a4f1ef7-5fb5-4d0e-bef5-2ce0e18b79d8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Brainstorm Cell Therapeutics Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BCLI',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3642a73c-3c51-4681-87bc-008078218aee'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Scorpius Holdings, Inc.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SCPX',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8b6ddae9-af27-45cf-9fd4-f74412fca927'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'AFRICAN AGRICULTURE HLDGS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AAGR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('db1e488b-9a66-4dee-b4d9-92b22de24dad'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Regencell Bioscience Holdings Limited Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'RGC',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('16e2c23f-ac1d-4585-9813-874e9b280624'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'FIRST REP BK SAN FRANCISCO CALIF NEW COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FRCB',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('fd874baf-13ce-43b8-966c-d7cb8475d134'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SMILEDIRECTCLUB INC CL A',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SDCCQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('cd1812da-5e16-4b0c-b126-9e5930054985'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Palatin Technologies, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'PTNT',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('c1b354f1-54b5-41d2-8d3a-45dabc093f73'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'AZUL S A SPONSORED ADR REPSTG PFD American Depositary Shares - '
#              'Sponsored',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AZULQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('72ae41a8-6350-4afc-ac4a-2546bf8e8717'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'MicroAlgo, Inc. Class A Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MLGO',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6358e6de-566c-4978-87ac-7aeed11e0945'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Remark Holdings Inc Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MARK',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('74b9e459-2fe1-47f1-abe9-c5d4e1933aa1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'LI-CYCLE HLDGS CORP Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LICYQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('167f9024-b03a-47bc-bae5-0e70d3e4f0b2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'NU RIDE INC CL A NEW',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'NRDE',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('1f5e1b62-4778-4dbe-8c3a-c1917561011f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'LILIUM N V Ordinary Shares (Netherlands)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LILMF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6bcc707c-0e4b-476b-a4d0-7ca50ffe7e88'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Unity Biotechnology, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'UNBX',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('93804887-e964-47db-8736-e1ffe8cfedd6'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'BOLLINGER INNOVATIONS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BINI',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('c97800de-5f33-436f-b1ed-5c5d27180e3d'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SEELOS THERAPEUTICS INC COM PAR NEW $0.001',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SEELQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('eb4b0940-ace7-4746-8593-10c9dbdafbb7'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'AKOUSTIS TECHNOLOGIES INC COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AKTSQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('725765a7-46bd-4dad-b8cb-0583d2ccca09'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'PYROGENESIS INC Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'PYRGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('448aeb30-eaad-40a2-96ad-33836d7e0ad6'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'WiMi Hologram Cloud Inc. Class B Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'WIMI',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('420c3bd9-4086-45f1-a95f-978717c57971'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SPI Energy Co., Ltd. Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SPIEF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('6cbde763-4826-4aaa-8470-8854b324778f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ORANGE American Depositary Shares - Sponsored (France)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ORANY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('b64671e3-d25c-47a9-bc11-60906bddf711'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ELYS BMG GROUP, INC. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ELYS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8dcfdca2-32ff-446d-9c4a-5c7f63570ac3'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'VINCO VENTURES INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BBIG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f65541b2-fd67-4bf3-aa1c-4c62251ae8b0'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'NORTHERN STAR INVT CORP II COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'NSTB',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('4fc6fdbf-d33a-417d-bc59-a3393c138bc8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ORGENESIS INC COM PAR $0.0001',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ORGS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('87586b24-4383-428d-85ad-9fbdc89e9e46'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'LL Flooring Holdings Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LLFLQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f2fa24fa-be31-418a-aa9f-55f07eac9227'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Biotricity Inc. COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BTCY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('7d792050-fd9e-484f-884c-8d21439af9a4'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SAFEGUARD SCIENTIFICS INC COM PAR $',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SFES',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6c77c4b3-8860-44a2-80c6-5f15d9d3daff'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'USD PARTNERS LP COM UNIT REPSTG LTD PARTNER INTS',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'USDP',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('ae8ee317-bb23-4acb-aec7-4e18a0b2f638'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ATRECA INC CL A COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BCEL',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('70582ae9-3846-4942-b0f8-cc4325ae7200'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'RENALYTIX PLC American Depositary Shares - Sponsored',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'RNLXY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('e75a2480-9475-47c4-b6bd-1287960a6ee2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ModivCare Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MODVQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('89600001-ea10-4f8a-a083-014d588261a5'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'TINGO GROUP INC COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'TIOG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3fb80fdf-59d4-4ee1-8ee7-9f2b64933146'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'IDEANOMICS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'IDEXQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('d203e8ab-228f-4753-9f4d-d413b7719f22'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Allego N.V. Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ALLGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('44d431bd-187a-4347-9b05-0d7d1f0ded31'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'EFFECTOR THERAPEUTICS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'EFTR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('8df729b2-2345-460d-809c-59f6c7980c17'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'VERADIGM INC COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MDRX',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('93a99b09-984f-4093-b0d3-22710de4999c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Alpine 4 Holdings, Inc. Cl A New Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ALPP',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('ef8c07a7-4577-44c1-8c44-2207b69559e5'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CONX Corp Class A Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'CNXX',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a4052fda-a8a6-4403-aafc-a00f0a15d1d8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SORRENTO THERAPEUTICS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SRNE',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('0a7e786f-04dd-4ae5-92a0-dad83995e3e8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ContextLogic Holdings Inc. Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'LOGC',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8fcd0a88-1cbb-4e2f-b986-b546ec42a77b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CAMBER ENERGY INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'CEIN',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('b338b9c5-c49b-4ede-8d2d-7855801612b3'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'EDGIO INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'EGIOQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('ab4360d2-59c7-4633-9297-46a4855ba718'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CANOO INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'GOEVQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('5dc148f6-428d-40c1-bb35-e647cd91cd2b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Affimed N.V.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AFMDQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('4069d4f6-c7fc-421a-ad01-94483c5f9dec'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'TEMPO AUTOMATION HLDGS INC',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'TMPOQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f8672a5b-e677-43f8-b647-e0901caebc85'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'EXELA TECHNOLOGIES INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'XELA',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3474ad4f-51a7-4770-b5b7-615fbd663363'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Silvergate Capital Corporation Class A Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SICPQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f644fe3f-eca9-4135-aa8b-353d1267017e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'VBI VACCINES INC CDA Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'VBIVQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('86232fb3-8c7d-445e-acba-36d9b05c3e8f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Enthusiast Gaming Holdings Inc.',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'EGLXF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('a3535bfe-4bbc-4711-95e4-4ffb469a2b51'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GOL LINHAS AEREAS INTELIGENTES SA American Depositary Receipts - '
#              'Sponsored',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'GOLLQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8332396f-6baf-49b1-8717-e51da871b4a9'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'BETTER THERAPEUTICS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BTTX',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('944254aa-a7fe-4e42-8380-0221986e4af9'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Amyris, Inc. Com New',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AMRSQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('d5f52df3-3f8b-4e39-8ee2-deb2c8f73b34'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'BIG LOTS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'BIGGQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('14c154f9-2cd9-48f9-ae03-dbbd060be620'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Superior Industries International, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'SSUP',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('a7d33440-eca9-437d-a0e5-7ef0febb5201'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'EAGLE PHARMACEUTICALS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'EGRX',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('2687daf0-557e-40e6-8463-c09b1b747007'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'ACUTUS MED INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AFIB',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('1d4057ea-2549-477b-89b9-a524437ec1ee'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GALERA THERAPEUTICS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'GRTX',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('9144c3a2-0712-4a46-a0d6-1848e02996ee'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'INVITAE CORP COM',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'NVTAQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('4b91a379-7312-43c5-b2db-aa81cdf05e85'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'VICINITY MTR CORP Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'VEVMQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3e7f0314-d2c5-43ac-95ef-ab2d5a0a4d2f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': '23ANDME HLDG CO CL A Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'MEHCQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('dcd5dcc4-ad02-45c5-a5d2-8892680e593a'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kubient, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'KBNT',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': True,
#      'id': UUID('bacba6c3-8908-4d1f-be0d-4e8fc193ef5b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
# ...
#      'name': 'State Street SPDR Bloomberg Investment Grade Floating Rate ETF',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLRN',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('1810d8ad-df12-4d78-a90a-98b8769bf694'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Flowserve Corporation',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLS',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('38f54757-9bb4-44e5-bddb-2b1c805b7c0e'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'VanEck IG Floating Rate ETF',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLTR',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('4ebc17de-3948-451c-924a-fcc51c6b04bf'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Flutter Entertainment plc',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLUT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('f313a403-49fc-482f-8407-2d58d4ed5c43'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Flux Power Holdings, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLUX',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('db4c8f34-b59c-4c26-a143-5e607afd4a1f'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': '1-800-FLOWERS.COM, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLWS',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('615fb424-a499-43ba-847b-b0214e82ab49'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Firefly Aerospace Inc. Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLY',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.BATS: 'BATS'>,
#      'fractionable': False,
#      'id': UUID('6be2edc6-af4b-46d4-9100-17184b75403f'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Tradr 2X Long FLY Daily ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLYT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('86984f7a-cb86-4730-add6-e47a49facd9d'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Flywire Corporation Voting Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FLYW',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('1a2f40d4-ded0-4a31-ade1-02e5c276a4c1'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Farmers & Merchants Bancorp, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMAO',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('0977dc29-229b-4344-9ff6-5cde45fab716'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fidelity MSCI Materials Index ETF',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMAT',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('83d8dd21-b32e-4815-8f65-c66d2074d665'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'First Mid Bancshares, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMBH',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('caae509d-0797-4704-b4e5-0028c73c802c'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'FMC Corporation',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': False,
#      'id': UUID('2ae79eb1-cfcd-4e68-b4d2-3e78ea92983a'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fidelity Enhanced Mid Cap ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMDE',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('d4749b88-823e-4963-bf32-57343ecb95b4'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fidelity Covington Trust Fidelity Metaverse ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMET',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': True,
#      'id': UUID('87e10238-6e47-44dd-9768-d355f29378da'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Farmers National Banc Corp. Common Stock',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMNB',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('470c02e2-a501-4aba-9a3a-7238f6fb293e'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fresenius Medical Care AG',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMS',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('3597d68f-c92d-4cf4-8054-e9c5c65a88f8'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'FOMENTO ECONOMICO MEXICANO, S.A.B. DE C.V.',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FMX',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('efab651c-58bf-4240-a7f9-36e3c413c1c1'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fabrinet',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FN',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('2ee87cf7-1130-463d-ad45-bcfbd7baf23f'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'F.N.B. Corp',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FNB',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('04ab870e-3c0d-4a28-a552-4014b02fa953'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Fidelity MSCI Financials Index ETF',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FNCL',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.NYSE: 'NYSE'>,
#      'fractionable': True,
#      'id': UUID('dbc1365f-703f-4dc2-82e9-37b005f17ae5'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Floor & Decor Holdings, Inc.',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FND',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('70b9ecaf-b41f-49ae-8c8f-5a4e70826d97'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Schwab Fundamental U.S. Small Company ETF',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FNDA',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('d616b811-e923-445e-9d61-b853d52dd3a4'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Schwab Fundamental U.S. Broad Market ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FNDB',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('76790dd3-b1c8-4ade-9fe8-32b5ef5feacd'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Schwab Fundamental International Small Equity ETF',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FNDC',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('0d9805ca-776d-483e-ac23-1d79c53c6334'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Schwab Fundamental Emerging Markets Equity ETF',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FNDE',
#      'tradable': True},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': ['fractional_eh_enabled', 'has_options'],
#      'easy_to_borrow': True,
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'fractionable': True,
#      'id': UUID('adb772ca-c2fa-4c4b-bdc3-b9b3c790fcfd'),
#      'maintenance_margin_requirement': 30.0,
#      'marginable': True,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Schwab Fundamental International Equity ETF',
#      'price_increment': None,
#      'shortable': True,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'FNDF',
#      'tradable': True},
#  ...]

# %% [markdown]
# ### 6. Get list of options contracts for the given symbol (e.g. SPY)

# %%
# In this instance, we retrieve the necessary contracts based on the parameters we've configured.
# specify underlying symbol

underlying_symbol = "NVDA"
req = GetOptionContractsRequest(
    underlying_symbol=[underlying_symbol],  
    # specify asset status: active (default)
    status=AssetStatus.ACTIVE,   
    # specify expiration date (specified date + 1 day range)
    expiration_date = None,
    # we can pass a date object or string (YYYY-MM-DD) to specify an expiration date range
    expiration_date_gte = None,                            
    expiration_date_lte = None, 
    # specify root symbol
    root_symbol = None,
    # specify option type (ContractType.CALL or ContractType.PUT)
    type = None,  
)

res = trade_client.get_option_contracts(req)
res
# Out:
# {   'next_page_token': 'MTAw',
#     'option_contracts': [   {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '125f8a90-8494-469c-a1d2-b1d58916da6c',
#                                 'name': 'AA Nov 07 2025 20 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 20.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00020000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'b1e5a56a-e764-46b5-b471-18d99ab2d6fb',
#                                 'name': 'AA Nov 07 2025 21 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 21.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00021000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '32fa4933-4108-4fb7-9ee5-b67616ee0592',
#                                 'name': 'AA Nov 07 2025 22 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 22.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00022000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '3a8fea1f-c0ed-404c-8b0e-44c2602b4f00',
#                                 'name': 'AA Nov 07 2025 23 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 23.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00023000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '72e001fa-f4d1-44ff-ac90-73f268009ca9',
#                                 'name': 'AA Nov 07 2025 24 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 24.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00024000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '10.34',
#                                 'close_price_date': datetime.date(2025, 10, 17),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'e9eeb817-8cae-4200-bbc2-aa77432fdd6e',
#                                 'name': 'AA Nov 07 2025 25 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 25.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00025000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '4fd67b8b-7f27-4a81-a79d-d3f3639ee499',
#                                 'name': 'AA Nov 07 2025 26 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 26.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00026000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '84fc1991-c88c-4077-930c-5604e0340a49',
#                                 'name': 'AA Nov 07 2025 26.5 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 26.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00026500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '5670725d-7112-43e0-91ba-406e4dece31a',
#                                 'name': 'AA Nov 07 2025 27 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 27.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00027000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '3fe418d9-deda-400e-bd2c-126a5b70e033',
#                                 'name': 'AA Nov 07 2025 27.5 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 27.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00027500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '7.9',
#                                 'close_price_date': datetime.date(2025, 10, 22),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '1c07ce1d-ca64-4955-8476-1b65f740ec61',
#                                 'name': 'AA Nov 07 2025 28 Call',
#                                 'open_interest': '2',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 28.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00028000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '009997a1-8802-4792-aeb8-4a4df4650589',
#                                 'name': 'AA Nov 07 2025 28.5 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 28.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00028500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '0277cb6e-4bd3-403e-8dab-c79c666df6a8',
#                                 'name': 'AA Nov 07 2025 29 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 29.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00029000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '6c6bba27-4655-4073-81e0-7d0e6adf2198',
#                                 'name': 'AA Nov 07 2025 29.5 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 29.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00029500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '7.43',
#                                 'close_price_date': datetime.date(2025, 10, 30),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '393d10e7-390c-4266-ae37-c5aa6b33d7c4',
#                                 'name': 'AA Nov 07 2025 30 Call',
#                                 'open_interest': '7',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 30.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00030000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '6.85',
#                                 'close_price_date': datetime.date(2025, 10, 21),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'ed18a41a-afde-4f13-bfe3-4de47be5210d',
#                                 'name': 'AA Nov 07 2025 30.5 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 30.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00030500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '6.41',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '976569c3-0ad0-4d3f-b732-ea561d3fc384',
#                                 'name': 'AA Nov 07 2025 31 Call',
#                                 'open_interest': '7',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 31.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00031000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '5.63',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '93a1cfdc-4d1a-4f0f-90ad-ed306121bffd',
#                                 'name': 'AA Nov 07 2025 31.5 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 31.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00031500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '4.72',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '991762f1-bd98-4abe-a02b-d0e6796cba64',
#                                 'name': 'AA Nov 07 2025 32 Call',
#                                 'open_interest': '8',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 32.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00032000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '7.07',
#                                 'close_price_date': datetime.date(2025, 10, 29),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'bbf7e06f-e9ca-46b9-898e-f10fa04064f0',
#                                 'name': 'AA Nov 07 2025 32.5 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 32.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00032500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '3.81',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'a97b3f99-0683-4dd4-be4b-bdb4fbf2f368',
#                                 'name': 'AA Nov 07 2025 33 Call',
#                                 'open_interest': '31',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 33.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00033000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '6.73',
#                                 'close_price_date': datetime.date(2025, 10, 27),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '85e21534-b6a8-4d40-9d28-019dc3833c75',
#                                 'name': 'AA Nov 07 2025 33.5 Call',
#                                 'open_interest': '8',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 33.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00033500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '6.65',
#                                 'close_price_date': datetime.date(2025, 10, 23),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '369db94d-2449-4e99-a41d-5e80f7756e8b',
#                                 'name': 'AA Nov 07 2025 34 Call',
#                                 'open_interest': '47',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 34.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00034000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '5.25',
#                                 'close_price_date': datetime.date(2025, 10, 29),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '10d56916-8692-4211-b778-61382b61f492',
#                                 'name': 'AA Nov 07 2025 34.5 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 34.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00034500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.53',
#                                 'close_price_date': datetime.date(2025, 10, 30),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '092c9727-5e9c-4044-b652-61b4c3263dcd',
#                                 'name': 'AA Nov 07 2025 35 Call',
#                                 'open_interest': '36',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 35.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00035000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '1.79',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '89721d33-b196-408c-9235-775d66a5275c',
#                                 'name': 'AA Nov 07 2025 35.5 Call',
#                                 'open_interest': '49',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 35.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00035500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '1.42',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '6a218c28-d09c-4cf6-9044-4b493d8c561c',
#                                 'name': 'AA Nov 07 2025 36 Call',
#                                 'open_interest': '224',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 36.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00036000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '1.13',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '41324d9e-6475-4f03-b612-74fda8f38c89',
#                                 'name': 'AA Nov 07 2025 36.5 Call',
#                                 'open_interest': '67',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 36.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00036500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.86',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '03e0d3d1-1efc-4e8f-b77b-7a98e17e69da',
#                                 'name': 'AA Nov 07 2025 37 Call',
#                                 'open_interest': '295',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 37.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00037000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.65',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'cc2db1e8-29ca-4943-8aa6-29e7f6e24ca9',
#                                 'name': 'AA Nov 07 2025 37.5 Call',
#                                 'open_interest': '154',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 37.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00037500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.52',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'b4c8443a-3a73-434b-8ae0-805ce7ae8026',
#                                 'name': 'AA Nov 07 2025 38 Call',
#                                 'open_interest': '225',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 38.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00038000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.41',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '237147f1-713b-46f4-9f16-f662ae10c231',
#                                 'name': 'AA Nov 07 2025 38.5 Call',
#                                 'open_interest': '43',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 38.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00038500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.3',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '53cc4dcd-d137-4177-8002-76ffaf7fc851',
#                                 'name': 'AA Nov 07 2025 39 Call',
#                                 'open_interest': '856',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 39.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00039000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.21',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '01c7146f-77f0-4b2e-b3c5-7426a649a070',
#                                 'name': 'AA Nov 07 2025 39.5 Call',
#                                 'open_interest': '246',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 39.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00039500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.16',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '1c2a3890-ee7a-4875-9802-1b9907c9ab23',
#                                 'name': 'AA Nov 07 2025 40 Call',
#                                 'open_interest': '278',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 40.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00040000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.11',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '888ba77d-68d3-42c1-ab34-5a29e43d0be7',
#                                 'name': 'AA Nov 07 2025 40.5 Call',
#                                 'open_interest': '1247',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 40.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00040500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.08',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '564d2245-bfa9-4ae7-9dd4-5d4c4d578057',
#                                 'name': 'AA Nov 07 2025 41 Call',
#                                 'open_interest': '194',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 41.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00041000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'e0a3d6c4-8c71-44c0-bffa-6226e9e75c0e',
#                                 'name': 'AA Nov 07 2025 41.5 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 41.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00041500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.06',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'a7b5d771-dfdc-4b46-948d-439264d079c7',
#                                 'name': 'AA Nov 07 2025 42 Call',
#                                 'open_interest': '321',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 42.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00042000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'c85b6616-00ae-42a6-b5f8-0629b1033729',
#                                 'name': 'AA Nov 07 2025 42.5 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 42.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00042500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.04',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '0f98dd82-00c6-4ece-b3c5-d33e7a727bfc',
#                                 'name': 'AA Nov 07 2025 43 Call',
#                                 'open_interest': '138',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 43.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00043000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.34',
#                                 'close_price_date': datetime.date(2025, 10, 29),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'c1fa5c01-72e1-416d-88f9-c139103cfdd8',
#                                 'name': 'AA Nov 07 2025 43.5 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 43.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107C00043500',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.03',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'a03b5c4e-0a40-4389-b427-d4d1b83d3fac',
#                                 'name': 'AA Nov 07 2025 44 Call',
#                                 'open_interest': '127',
# ...
#                             {   'close_price': '0.49',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '9de865c1-25e2-4c25-932f-d65ab9e38429',
#                                 'name': 'AA Nov 07 2025 35.5 Put',
#                                 'open_interest': '127',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 35.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00035500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.73',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'bc9e1761-2212-4007-b93b-3a7429b390ef',
#                                 'name': 'AA Nov 07 2025 36 Put',
#                                 'open_interest': '1254',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 36.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00036000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '0.89',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'f0f73c1e-e437-4dd4-8c78-2a9cd667c3a8',
#                                 'name': 'AA Nov 07 2025 36.5 Put',
#                                 'open_interest': '228',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 36.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00036500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '1.19',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '7def8bd9-17de-4a21-8a10-cbad07dc5573',
#                                 'name': 'AA Nov 07 2025 37 Put',
#                                 'open_interest': '247',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 37.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00037000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '1.45',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '1226c3ca-67d9-47f3-aad9-5f8b1f200d6f',
#                                 'name': 'AA Nov 07 2025 37.5 Put',
#                                 'open_interest': '185',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 37.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00037500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '1.85',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'b7d54b62-19cb-40e8-a808-124978a9d486',
#                                 'name': 'AA Nov 07 2025 38 Put',
#                                 'open_interest': '1751',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 38.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00038000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.22',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'e894dbb3-f175-4d3e-bd87-6a18b64ab9bd',
#                                 'name': 'AA Nov 07 2025 38.5 Put',
#                                 'open_interest': '141',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 38.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00038500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.6',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '044cff18-154a-4d37-a088-a90df501e4d6',
#                                 'name': 'AA Nov 07 2025 39 Put',
#                                 'open_interest': '376',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 39.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00039000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '3.03',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'a47c1521-aeaf-4654-a7b3-a03308cb0ca5',
#                                 'name': 'AA Nov 07 2025 39.5 Put',
#                                 'open_interest': '231',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 39.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00039500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '3.4',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '976aca2f-886b-441a-9db2-79c22fa8a775',
#                                 'name': 'AA Nov 07 2025 40 Put',
#                                 'open_interest': '327',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 40.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00040000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.03',
#                                 'close_price_date': datetime.date(2025, 10, 27),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '96cda81b-8edd-4e89-b60e-59d167a044f3',
#                                 'name': 'AA Nov 07 2025 40.5 Put',
#                                 'open_interest': '37',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 40.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00040500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '4.34',
#                                 'close_price_date': datetime.date(2025, 10, 30),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '63b5b3d3-5030-46d4-a5e6-440be630a0df',
#                                 'name': 'AA Nov 07 2025 41 Put',
#                                 'open_interest': '86',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 41.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00041000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '44c9ab12-4ea0-45dd-8106-e2ae8b42be54',
#                                 'name': 'AA Nov 07 2025 41.5 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 41.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00041500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.2',
#                                 'close_price_date': datetime.date(2025, 10, 29),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '3ec7f998-8eac-4027-a95e-5c4c0f89575f',
#                                 'name': 'AA Nov 07 2025 42 Put',
#                                 'open_interest': '75',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 42.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00042000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'}]}

# %% [markdown]
# ### 7. Get options contract by symbol

# %%
symbol = res.option_contracts[0].symbol
contract = trade_client.get_option_contract(symbol)
contract
# Out:
# {   'close_price': None,
#     'close_price_date': None,
#     'expiration_date': datetime.date(2025, 11, 7),
#     'id': '125f8a90-8494-469c-a1d2-b1d58916da6c',
#     'name': 'AA Nov 07 2025 20 Call',
#     'open_interest': None,
#     'open_interest_date': None,
#     'root_symbol': 'AA',
#     'size': '100',
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'strike_price': 20.0,
#     'style': <ExerciseStyle.AMERICAN: 'american'>,
#     'symbol': 'AA251107C00020000',
#     'tradable': True,
#     'type': <ContractType.CALL: 'call'>,
#     'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#     'underlying_symbol': 'AA'}

# %% [markdown]
# ### 8. Get options contract by id

# %%
contract_id = res.option_contracts[0].id
contract = trade_client.get_option_contract(symbol_or_id=contract_id)
contract
# Out:
# {   'close_price': None,
#     'close_price_date': None,
#     'expiration_date': datetime.date(2025, 11, 7),
#     'id': '125f8a90-8494-469c-a1d2-b1d58916da6c',
#     'name': 'AA Nov 07 2025 20 Call',
#     'open_interest': None,
#     'open_interest_date': None,
#     'root_symbol': 'AA',
#     'size': '100',
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'strike_price': 20.0,
#     'style': <ExerciseStyle.AMERICAN: 'american'>,
#     'symbol': 'AA251107C00020000',
#     'tradable': True,
#     'type': <ContractType.CALL: 'call'>,
#     'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#     'underlying_symbol': 'AA'}

# %% [markdown]
# ### 9. Get put options contracts
# Please note that the stock SPY is used as an example and should not be considered investment advice.

# %%
# We can filter the contracts that are relevant to us by specifying various option properties like expiration date range (the contracts which are expiring within a particular time window), strike range (the contracts with strike prices within a given range), style of expiration for the option contract (like American or European), etc.

underlying_symbol = "NVDA"

# specify expiration date range
now = datetime.now(tz=ZoneInfo("America/New_York"))
day1 = now + timedelta(days=1)
day60 = now + timedelta(days=60)

req = GetOptionContractsRequest(
    # specify underlying symbol
    underlying_symbol = [underlying_symbol],
    # specify asset status: active (default)
    status = AssetStatus.ACTIVE,
    # specify expiration date (specified date + 1 day range)
    expiration_date = None,
    # we can pass date object or string
    expiration_date_gte = day1.date(),
    expiration_date_lte = day60.strftime(format="%Y-%m-%d"),
    # specify root symbol
    root_symbol = None,
    # specify option type: put
    type = ContractType.PUT,    
    # specify option style: american
    style = ExerciseStyle.AMERICAN,
    # specify strike price range
    strike_price_gte = None,
    strike_price_lte = None,
    # specify limit
    limit = 100,
    # specify page
    page = None
)

res = trade_client.get_option_contracts(req)
res
# Out:
# {   'next_page_token': 'MTAw',
#     'option_contracts': [   {   'close_price': '0.04',
#                                 'close_price_date': datetime.date(2025, 10, 28),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '501521ea-f020-4c98-a61f-4638bd01113b',
#                                 'name': 'A Nov 21 2025 55 Put',
#                                 'open_interest': '5',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 55.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00055000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.65',
#                                 'close_price_date': datetime.date(2025, 4, 25),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '74bfc285-f408-4a1f-8d50-4bfe6cc1b158',
#                                 'name': 'A Nov 21 2025 60 Put',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 60.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00060000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.14',
#                                 'close_price_date': datetime.date(2025, 7, 8),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'dca756bd-d3d8-4a12-90c7-ad116be4120b',
#                                 'name': 'A Nov 21 2025 65 Put',
#                                 'open_interest': '2',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 65.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00065000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.05',
#                                 'close_price_date': datetime.date(2025, 8, 28),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'c7812a34-0ce2-43a3-9b67-4203031d5089',
#                                 'name': 'A Nov 21 2025 70 Put',
#                                 'open_interest': '23',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 70.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00070000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 9, 3),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'a4ed11d5-eb86-4d8b-9da3-c11fd56828a4',
#                                 'name': 'A Nov 21 2025 75 Put',
#                                 'open_interest': '2',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 75.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00075000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 10, 8),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '3fff88e5-6e63-4985-a9c5-13e065563a74',
#                                 'name': 'A Nov 21 2025 80 Put',
#                                 'open_interest': '4',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 80.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00080000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.1',
#                                 'close_price_date': datetime.date(2025, 9, 29),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '460380a7-2674-4a5a-be6f-bc78b04ee28a',
#                                 'name': 'A Nov 21 2025 85 Put',
#                                 'open_interest': '19',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 85.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00085000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.66',
#                                 'close_price_date': datetime.date(2025, 8, 18),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'd0af44b7-e8f3-4a44-b3e0-b820fea45ff8',
#                                 'name': 'A Nov 21 2025 90 Put',
#                                 'open_interest': '83',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 90.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00090000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.05',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'b9de613a-5d0c-4ded-90f5-313056294954',
#                                 'name': 'A Nov 21 2025 95 Put',
#                                 'open_interest': '31',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 95.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00095000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.1',
#                                 'close_price_date': datetime.date(2025, 10, 8),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '4cf132ff-57d2-48a8-9bbc-f27194e7ab18',
#                                 'name': 'A Nov 21 2025 100 Put',
#                                 'open_interest': '82',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 100.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00100000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.23',
#                                 'close_price_date': datetime.date(2025, 10, 22),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '376255b2-7d2c-4006-9c15-7cadaca2da69',
#                                 'name': 'A Nov 21 2025 105 Put',
#                                 'open_interest': '125',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 105.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00105000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.29',
#                                 'close_price_date': datetime.date(2025, 10, 22),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '6766a8ab-4fcb-4334-b663-afd54557b314',
#                                 'name': 'A Nov 21 2025 110 Put',
#                                 'open_interest': '171',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 110.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00110000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.2',
#                                 'close_price_date': datetime.date(2025, 10, 21),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'dce20dab-458c-42cb-8dcb-d5d5a9f25569',
#                                 'name': 'A Nov 21 2025 115 Put',
#                                 'open_interest': '86',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 115.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00115000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.35',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '0051d115-6179-4d9a-aba2-5f90cf019fca',
#                                 'name': 'A Nov 21 2025 120 Put',
#                                 'open_interest': '98',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 120.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00120000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.41',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '9d2381b7-354c-4621-a822-c8786ab3c557',
#                                 'name': 'A Nov 21 2025 125 Put',
#                                 'open_interest': '174',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 125.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00125000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.75',
#                                 'close_price_date': datetime.date(2025, 10, 30),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '837877f4-e23b-46d0-8a76-2ac2f6bb7570',
#                                 'name': 'A Nov 21 2025 130 Put',
#                                 'open_interest': '225',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 130.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00130000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.9',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'e0fa5d49-573f-48a6-9fd6-127b047de892',
#                                 'name': 'A Nov 21 2025 135 Put',
#                                 'open_interest': '352',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 135.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00135000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '1.68',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '37cd4b63-a661-4d4b-8a7c-943678473e8c',
#                                 'name': 'A Nov 21 2025 140 Put',
#                                 'open_interest': '115',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 140.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00140000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '3.42',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '5f0a807e-2260-42cb-b078-d57df170944b',
#                                 'name': 'A Nov 21 2025 145 Put',
#                                 'open_interest': '92',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 145.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00145000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '6.3',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'bce2a2ba-ead0-4f34-bf51-47e7eb14454f',
#                                 'name': 'A Nov 21 2025 150 Put',
#                                 'open_interest': '12',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 150.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00150000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '685b674e-20ba-4af8-bff6-a5fd9cbfec0f',
#                                 'name': 'A Nov 21 2025 155 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 155.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00155000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '808efcd9-e530-455e-be3a-8da174126339',
#                                 'name': 'A Nov 21 2025 160 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 160.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00160000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '948c656e-11b2-46e4-8730-7c31abf0e9ef',
#                                 'name': 'A Nov 21 2025 165 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 165.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00165000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': 'bb18913e-8453-40d4-97ca-72cc5d12edf5',
#                                 'name': 'A Nov 21 2025 170 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 170.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00170000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 21),
#                                 'id': '3fc4a0a5-b272-4374-805a-c7b71790e85a',
#                                 'name': 'A Nov 21 2025 175 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 175.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251121P00175000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '513c480a-e525-4bb4-8f44-2d09afccbfe8',
#                                 'name': 'A Dec 19 2025 65 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 65.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00065000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '38992ad0-426c-4a1e-9010-e68e3253e528',
#                                 'name': 'A Dec 19 2025 70 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 70.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00070000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '3444e54c-0e9d-42ec-a158-c5f2cf8204ae',
#                                 'name': 'A Dec 19 2025 75 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 75.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00075000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '6e7df839-3fc4-4e30-b6e8-91724eeaa187',
#                                 'name': 'A Dec 19 2025 80 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 80.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00080000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '003fa69d-6d54-4296-8264-6a2a6a5cea56',
#                                 'name': 'A Dec 19 2025 85 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 85.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00085000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '13e5ee82-d926-4a31-b9f9-d2c2be3e5bec',
#                                 'name': 'A Dec 19 2025 90 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 90.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00090000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.61',
#                                 'close_price_date': datetime.date(2025, 9, 25),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '1f950c04-27ad-443b-a368-760158194293',
#                                 'name': 'A Dec 19 2025 95 Put',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 95.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00095000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.75',
#                                 'close_price_date': datetime.date(2025, 9, 22),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': 'd8b5f7e2-be93-4e3f-8a7c-9c19b5d488a9',
#                                 'name': 'A Dec 19 2025 100 Put',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 100.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00100000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.6',
#                                 'close_price_date': datetime.date(2025, 10, 15),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '728a1ef8-e2ab-4e99-9a40-147358797e8d',
#                                 'name': 'A Dec 19 2025 105 Put',
#                                 'open_interest': '100',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 105.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00105000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '2.65',
#                                 'close_price_date': datetime.date(2025, 9, 25),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '7d8b72e6-c0f0-4d03-b362-4633de0d1061',
#                                 'name': 'A Dec 19 2025 110 Put',
#                                 'open_interest': '156',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 110.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00110000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '0.51',
#                                 'close_price_date': datetime.date(2025, 10, 29),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': 'ae1741e5-29ce-4eaf-9d2b-653c1bcc2bd4',
#                                 'name': 'A Dec 19 2025 115 Put',
#                                 'open_interest': '133',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 115.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00115000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '1',
#                                 'close_price_date': datetime.date(2025, 10, 29),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '362a9bfc-bb06-4983-ac0a-314a81ace446',
#                                 'name': 'A Dec 19 2025 120 Put',
#                                 'open_interest': '33',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 120.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00120000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '1.4',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '04e5407e-1f80-4ecc-a3be-8cef3d8e27ed',
#                                 'name': 'A Dec 19 2025 125 Put',
#                                 'open_interest': '134',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 125.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00125000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '2.02',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': 'c5953221-b0de-44cd-9d48-8eb27b96149f',
#                                 'name': 'A Dec 19 2025 130 Put',
#                                 'open_interest': '177',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 130.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00130000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '2.7',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': 'f9684f57-b74e-4758-add1-deb939f9ff68',
#                                 'name': 'A Dec 19 2025 135 Put',
#                                 'open_interest': '630',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 135.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00135000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '4.1',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '8478773f-512d-40e7-bf6a-d5532c8f9d10',
#                                 'name': 'A Dec 19 2025 140 Put',
#                                 'open_interest': '66',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 140.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00140000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '7.2',
#                                 'close_price_date': datetime.date(2025, 10, 30),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': '5efd3ef6-ba0f-476d-bae2-f5863a72d9bc',
#                                 'name': 'A Dec 19 2025 145 Put',
#                                 'open_interest': '90',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'A',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 145.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'A251219P00145000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('7595a8d2-68a6-46d7-910c-6b1958491f5c'),
#                                 'underlying_symbol': 'A'},
#                             {   'close_price': '8.9',
#                                 'close_price_date': datetime.date(2025, 10, 23),
#                                 'expiration_date': datetime.date(2025, 12, 19),
#                                 'id': 'b2c2f3fa-a8eb-4529-b859-5a996a99a0d9',
#                                 'name': 'A Dec 19 2025 150 Put',
#                                 'open_interest': '2',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
# ...
#                                 'symbol': 'AA251107P00039500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '3.4',
#                                 'close_price_date': datetime.date(2025, 10, 31),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '976aca2f-886b-441a-9db2-79c22fa8a775',
#                                 'name': 'AA Nov 07 2025 40 Put',
#                                 'open_interest': '327',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 40.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00040000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.03',
#                                 'close_price_date': datetime.date(2025, 10, 27),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '96cda81b-8edd-4e89-b60e-59d167a044f3',
#                                 'name': 'AA Nov 07 2025 40.5 Put',
#                                 'open_interest': '37',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 40.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00040500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '4.34',
#                                 'close_price_date': datetime.date(2025, 10, 30),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '63b5b3d3-5030-46d4-a5e6-440be630a0df',
#                                 'name': 'AA Nov 07 2025 41 Put',
#                                 'open_interest': '86',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 41.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00041000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '44c9ab12-4ea0-45dd-8106-e2ae8b42be54',
#                                 'name': 'AA Nov 07 2025 41.5 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 41.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00041500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.2',
#                                 'close_price_date': datetime.date(2025, 10, 29),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '3ec7f998-8eac-4027-a95e-5c4c0f89575f',
#                                 'name': 'AA Nov 07 2025 42 Put',
#                                 'open_interest': '75',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 42.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00042000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'c2b81e24-808c-4514-ba62-6179d21ed60f',
#                                 'name': 'AA Nov 07 2025 42.5 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 42.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00042500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': '2.8',
#                                 'close_price_date': datetime.date(2025, 10, 23),
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': 'd564a283-45e4-4264-9af4-fe502ccbbdf4',
#                                 'name': 'AA Nov 07 2025 43 Put',
#                                 'open_interest': '5',
#                                 'open_interest_date': datetime.date(2025, 10, 30),
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 43.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00043000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '6f6fcc53-4e75-4ecd-9abd-b251de920a2a',
#                                 'name': 'AA Nov 07 2025 43.5 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 43.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00043500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '580391e2-fddd-4684-8166-48a18cb122d1',
#                                 'name': 'AA Nov 07 2025 44 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 44.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00044000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '753398c9-1486-48de-83a2-859c844ae9f7',
#                                 'name': 'AA Nov 07 2025 44.5 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 44.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00044500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '8fa5834e-4c8a-4ec5-a70d-ad6373817453',
#                                 'name': 'AA Nov 07 2025 45 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 45.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00045000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '8a0de499-e26f-4f3e-9f47-4c4584141e29',
#                                 'name': 'AA Nov 07 2025 45.5 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 45.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00045500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '513045c0-3f03-406d-9399-883843201ad1',
#                                 'name': 'AA Nov 07 2025 46 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 46.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00046000',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 11, 7),
#                                 'id': '50b1a5c8-8025-487d-86c0-165110ea2bef',
#                                 'name': 'AA Nov 07 2025 46.5 Put',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'AA',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 46.5,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'AA251107P00046500',
#                                 'tradable': True,
#                                 'type': <ContractType.PUT: 'put'>,
#                                 'underlying_asset_id': UUID('3ca0202f-01f4-41a0-bb0c-c8864e767ebd'),
#                                 'underlying_symbol': 'AA'}]}

# %% [markdown]
# ### 10. Get the highest open interest contract

# %%
# Filter contract with the highest open interest

max_open_interest = 0
high_open_interest_contract = None
for contract in res.option_contracts:
    oi = contract.open_interest
    if oi is not None:
        try:
            oi_int = int(oi)
            if oi_int > max_open_interest:
                max_open_interest = oi_int
                high_open_interest_contract = contract
        # skip if not convertible to int
        except ValueError:
            continue

# %% [markdown]
# ### 11. Explore information about the selected contract

# %%
# Check contract information like expiry, expiration style and contract status

#Check option expiry
print(high_open_interest_contract.expiration_date)

#Check option status
print(high_open_interest_contract.status)

#Check option exercise style
print(high_open_interest_contract.style)
# Out:
# 2025-11-07
# AssetStatus.ACTIVE
# ExerciseStyle.AMERICAN

# %% [markdown]
# ### 12. Place a long put option order
#
# **NOTE:**
# * On expiration days, option orders must be submitted before 3:15 p.m. ET and before 3:30 p.m. ET for broad-based ETFs like SPY and QQQ. Orders placed after these times will be rejected.
# * Expiring positions are auto-liquidated starting at 3:30 p.m. ET (options) and 3:45 p.m. ET (broad-based ETFs) for risk management.

# %%
# Execute either a Buy Call or Put option order in accordance with your trading strategy

req = MarketOrderRequest(
    symbol=high_open_interest_contract.symbol,
    qty=1,
    side=OrderSide.BUY,
    type=OrderType.MARKET,
    time_in_force=TimeInForce.DAY,
)
res = trade_client.submit_order(req)
res

# %% [markdown]
# ### 13. Get list of requested orders by specifying option contract symbol

# %%
req = GetOrdersRequest(
    status=QueryOrderStatus.ALL,
    symbols=[high_open_interest_contract.symbol],
    limit=2,
)
orders = trade_client.get_orders(req)
orders

# %% [markdown]
# ### 14. Filter order with the desired client_order_id and print the status
#
# The `client_order_id` parameter allows traders to specify their own identifier when submitting an order, enabling them to manage the order using their own reference

# %%
import uuid
client_order_id = f"order_{uuid.uuid4().hex[:8]}"

# Execute a Buy Call or Put option order with a custom client_order_id for order tracking and identification
req = MarketOrderRequest(
    symbol=high_open_interest_contract.symbol,
    qty=1,
    side=OrderSide.BUY,
    type=OrderType.MARKET,
    time_in_force=TimeInForce.DAY,
    client_order_id=client_order_id,
)
res = trade_client.submit_order(req)
res

# %%
# Extract order information by the custom client_order_id
trade_client.get_order_by_client_id(client_id=client_order_id)

# %% [markdown]
# ### 15. Get positions filtered by option contract symbol

# %%
# 15.1 Get all positions
positions = trade_client.get_all_positions()
positions

# %%
#15.2 Get open positions by symbol
positions = trade_client.get_open_position(
symbol_or_asset_id=high_open_interest_contract.symbol
)
positions

# %%
# 15.3 Get open positions by contract id
positions = trade_client.get_open_position(
symbol_or_asset_id=high_open_interest_contract.id
)
positions

# %%
# 15.4 check cost basis and unrealized profit/loss
# Show cost basis
print(positions.cost_basis)

# Show unrealized profit/loss
print(positions.unrealized_pl)

# %% [markdown]
# ### 16. Close the option position

# %%
trade_client.close_position(
    symbol_or_asset_id=high_open_interest_contract.symbol,
    close_options=ClosePositionRequest(qty="1")
)

# %% [markdown]
# ### 17. Trade Update (Stream)

# %%
# This allows the event loop to support `asyncio.run()` inside the notebook.
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
# Retrieve real-time live trade update data from the moment the order is placed until execution.
# Subscribe trade updates

trade_stream_client = TradingStream(TRADE_API_KEY, TRADE_API_SECRET, paper=ALPACA_PAPER_TRADE, url_override=TRADE_API_WSS)

async def trade_updates_handler(data):
    print(data)

trade_stream_client.subscribe_trade_updates(trade_updates_handler)
trade_stream_client.run()

# %% [markdown]
# ### 18. Market Data (Historical)

# %%
# setup option historical data client
option_historical_data_client = OptionHistoricalDataClient(TRADE_API_KEY, TRADE_API_SECRET, url_override=DATA_API_URL)

# get option latest quote by symbol
req = OptionLatestQuoteRequest(
    symbol_or_symbols=[high_open_interest_contract.symbol],
)
option_historical_data_client.get_option_latest_quote(req)

# %%
# get option latest trade by symbol
req = OptionLatestTradeRequest(
    symbol_or_symbols=[high_open_interest_contract.symbol],
)
option_historical_data_client.get_option_latest_trade(req)

# %%
# get option chain by underlying_symbol
req = OptionChainRequest(
    underlying_symbol=high_open_interest_contract.underlying_symbol,
)
option_historical_data_client.get_option_chain(req)

# %% [markdown]
# ### 19. Market Data (Stream)

# %%
# This allows the event loop to support `asyncio.run()` inside the notebook.
import nest_asyncio
nest_asyncio.apply()

# %%
# Live streaming of market data based on a collection of symbols or an individual symbol
option_data_stream_client = OptionDataStream(TRADE_API_KEY, TRADE_API_SECRET, url_override=OPTION_STREAM_DATA_WSS)

async def option_data_stream_handler(data):
    print(data)

symbols=[
    high_open_interest_contract.symbol,
]

option_data_stream_client.subscribe_quotes(option_data_stream_handler, *symbols) 
option_data_stream_client.subscribe_trades(option_data_stream_handler, *symbols)

option_data_stream_client.run()

# %% [markdown]
# ### 20. Place Multi-Leg Options Position
#
# **Note**:
# * The stock SPY is used as an example and should not be considered investment advice.
# * The example below utilizes one of the multi-leg option strategies called a long straddle.

# %%
# 20.1 Get the underlying stock price and define the strike range to narrow down the option chain.

# Define a underlying symbol we want to trade
underlying_symbol = 'SPY'

# Get the latest price of the underlying stock
def get_underlying_price(symbol):
    underlying_trade_request = StockLatestTradeRequest(symbol_or_symbols=symbol)
    underlying_trade_response = stock_data_client.get_stock_latest_trade(underlying_trade_request)
    return underlying_trade_response[symbol].price

# Get the latest price of the underlying stock
underlying_price = get_underlying_price(underlying_symbol)

# Define a 1% range around the underlying price 
STRIKE_RANGE = 0.01

# Set the minimum and maximum strike prices based on the underlying price
min_strike = str(underlying_price * (1 - STRIKE_RANGE))
max_strike = str(underlying_price * (1 + STRIKE_RANGE))

print(f"{underlying_symbol} price: {underlying_price}")

# %%
# 20.2 Define a function to find near at-the-money (ATM) options

# This is a function that will return a contract which minimizes the difference from a target price
def find_nearest_strike_contract(contracts, target_price):
    min_diff = 0
    min_contract = None
    for contract in contracts:
        diff = abs(float(contract.strike_price) - target_price)
        if min_contract is None or diff < min_diff:
            min_diff = diff
            min_contract = contract
    return min_contract

# %%
# 20.3 Narrow down the options to near-ATM options

# Obtain both call options and put options of the specified underlying asset
underlying_symbol = ['SPY']
order_legs = []

for c_type in [ContractType.CALL, ContractType.PUT]:
    print(c_type)
    req = GetOptionContractsRequest(
        underlying_symbols=underlying_symbol,
        status=AssetStatus.ACTIVE,
        expiration_date_gte = now.date() + timedelta(days=7),
        expiration_date_lte = now.date() + timedelta(days=8),
        style=ExerciseStyle.AMERICAN,
        strike_price_gte=min_strike,
        strike_price_lte=max_strike,
        type=c_type,
        page_token=None
    )
    # Get option chain of the underlying symbol for both contract types
    cts = trade_client.get_option_contracts(req)

    c = find_nearest_strike_contract(cts.option_contracts, underlying_price)
    if c is not None:
        order_legs.append(OptionLegRequest(
            symbol=c.symbol,
            side=OrderSide.BUY,
            ratio_qty=1
        ))
    else:
        print(f"No suitable contract found for {c_type}")

# We should see that the symbols are similar, like "SPY______C________" and "SPY______P________",
# with all values marked as "_" being the same in both symbols.
# Such is because we expect only the contract type (call or put, C or P) to be different.

order_legs

# %%
# 20.4 Place the order for both legs simultaneously to execute the long straddle

# Set up an order request
req = MarketOrderRequest(
    qty=1,
    order_class=OrderClass.MLEG,
    time_in_force=TimeInForce.DAY,
    legs=order_legs
)
# place the order of the long straddle
res = trade_client.submit_order(req)
res
